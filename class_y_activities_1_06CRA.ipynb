# %% [markdown]
# <a href="https://colab.research.google.com/github/caraujom/Labs_IH/blob/main/class_y_activities_1_06CRA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm 
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
data=pd.read_csv('regression_data1.txt')

# %%
data
# Out:
#        HV1  IC1  IC2  IC3  IC4    IC5    AVGGIFT  TARGET_D
# 0     2346  420  446  468  503  14552  15.500000      21.0
# 1      497  350  364  357  384  11696   3.080000       3.0
# 2     1229  469  502  507  544  17313   7.500000      20.0
# 3      325  148  181  171  209   6334   6.700000       5.0
# 4      768  174  201  220  249   7802   8.785714      10.0
# ...    ...  ...  ...  ...  ...    ...        ...       ...
# 4838   701  297  335  405  468  15258  15.500000      25.0
# 4839  3357  284  455  343  447  24240  11.857143      19.0
# 4840   700  322  415  356  446  14360  11.333333      10.0
# 4841   601  206  225  251  289   9801  13.000000      25.0
# 4842   919  425  562  558  697  25784  17.923077      25.0
#
# [4843 rows x 8 columns]

# %%
y=data['TARGET_D']
X=data.drop('TARGET_D', axis=1)

# %%
X=sm.add_constant(X)
model=sm.OLS(y,X).fit ()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               TARGET_D   R-squared:                       0.272
# Model:                            OLS   Adj. R-squared:                  0.271
# Method:                 Least Squares   F-statistic:                     258.2
# Date:                Mon, 27 Mar 2023   Prob (F-statistic):               0.00
# Time:                        17:54:05   Log-Likelihood:                -18313.
# No. Observations:                4843   AIC:                         3.664e+04
# Df Residuals:                    4835   BIC:                         3.669e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.2092      0.503     12.346      0.000       5.223       7.195
# ...

# %%
X
# Out:
#       const   HV1  IC1  IC2  IC3  IC4    IC5    AVGGIFT
# 0       1.0  2346  420  446  468  503  14552  15.500000
# 1       1.0   497  350  364  357  384  11696   3.080000
# 2       1.0  1229  469  502  507  544  17313   7.500000
# 3       1.0   325  148  181  171  209   6334   6.700000
# 4       1.0   768  174  201  220  249   7802   8.785714
# ...     ...   ...  ...  ...  ...  ...    ...        ...
# 4838    1.0   701  297  335  405  468  15258  15.500000
# 4839    1.0  3357  284  455  343  447  24240  11.857143
# 4840    1.0   700  322  415  356  446  14360  11.333333
# 4841    1.0   601  206  225  251  289   9801  13.000000
# 4842    1.0   919  425  562  558  697  25784  17.923077
#
# [4843 rows x 8 columns]

# %%
variable=[1,2346,420,446,468,503,14552,15.5]

# %%
model.predict(variable)
# Out:
# array([18.05856205])

# %%
model.predict(X)
# Out:
# 0       18.058562
# 1        9.655263
# 2       13.162921
# 3       11.344440
# 4       12.838338
#           ...
# 4838    18.060741
# 4839    16.367150
# 4840    15.363279
# 4841    15.639838
# 4842    20.877292
# Length: 4843, dtype: float64

# %%
y
# Out:
# 0       21.0
# 1        3.0
# 2       20.0
# 3        5.0
# 4       10.0
#         ...
# 4838    25.0
# 4839    19.0
# 4840    10.0
# 4841    25.0
# 4842    25.0
# Name: TARGET_D, Length: 4843, dtype: float64

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm 
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
data=pd.read_csv('regression_data1.txt')

# %% [markdown]
# ¿Cuál es la diferencia entre una distribución normal y una distribución normal estándar?
#
# Repasa la documentación sobre la distribución uniforme.
#
# Discute el uso de la distribución uniforme para generar números aleatorios.

# %% [markdown]
# Trazar una distribución uniforme - documentación.

# %%
import numpy as np
import matplotlib.pyplot as plt


uniform_data = np.random.uniform(0, 1, 10000)# Generate 10,000 random numbers from a uniform distribution between 0 and 1


plt.hist(uniform_data, bins=20, density=True)# Plot the histogram of the generated data


plt.title('Uniform Distribution')# Add a title and axis labels
plt.xlabel('Values')# Add a title and axis labels
plt.ylabel('Probability Density')# Add a title and axis labels

plt.show()

# %%
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
data=pd.read_csv('regression_data1.txt')
data
# Out:
#        HV1  IC1  IC2  IC3  IC4    IC5    AVGGIFT  TARGET_D
# 0     2346  420  446  468  503  14552  15.500000      21.0
# 1      497  350  364  357  384  11696   3.080000       3.0
# 2     1229  469  502  507  544  17313   7.500000      20.0
# 3      325  148  181  171  209   6334   6.700000       5.0
# 4      768  174  201  220  249   7802   8.785714      10.0
# ...    ...  ...  ...  ...  ...    ...        ...       ...
# 4838   701  297  335  405  468  15258  15.500000      25.0
# 4839  3357  284  455  343  447  24240  11.857143      19.0
# 4840   700  322  415  356  446  14360  11.333333      10.0
# 4841   601  206  225  251  289   9801  13.000000      25.0
# 4842   919  425  562  558  697  25784  17.923077      25.0
#
# [4843 rows x 8 columns]

# %%
#target= m1*HV1 + m2*IC1 + m3*IC3 + m4*IC4 + m5*IC5 + m6*AVGGIFT
y=data['TARGET_D']
#por convención, los arreglos tipo vector/renglón/columna, se suelen poner con minúsculas
#y los arreglos tipo matriz, suelen llevan mayúsculas
#el método de OLS de STATSMODELS no te inclye la constante, hayq ue añadirla manuealmente
X=data.drop('TARGET_D',axis=1)
X=sm.add_constant(X)
model=sm.OLS(y,X).fit() #ordinary least squares (método de mínimos cuadrados) de lo que trata, es busca la mejor distancia de los puntos a las rectas
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               TARGET_D   R-squared:                       0.272
# Model:                            OLS   Adj. R-squared:                  0.271
# Method:                 Least Squares   F-statistic:                     258.2
# Date:                Mon, 27 Mar 2023   Prob (F-statistic):               0.00
# Time:                        21:02:39   Log-Likelihood:                -18313.
# No. Observations:                4843   AIC:                         3.664e+04
# Df Residuals:                    4835   BIC:                         3.669e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.2092      0.503     12.346      0.000       5.223       7.195
# ...

# %%
'''dife distribucion normal y dist standar : la normal es con los datos reales que tenemos , el ancho de la curv donde se guarda el 68% de los datos (desv standat). para standarizarla, guarda la forma de la dist que tenia y se hace la media cero, 
tienen media cero y donde se guarda el 68% de los datos siempre es 1  '''
# Out:
# 'dife distribucion normal y dist standar : la normal es con los datos reales que tenemos , el ancho de la curv donde se guarda el 68% de los datos (desv standat). para standarizarla, guarda la forma de la dist que tenia y se hace la media cero, \ntienen media cero y donde se guarda el 68% de los datos siempre es 1  '

# %%
''' distribucion uniforme,
