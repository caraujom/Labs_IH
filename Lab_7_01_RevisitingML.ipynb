# %% [markdown]
# <a href="https://colab.research.google.com/github/caraujom/Labs_IH/blob/main/Lab_7_01_RevisitingML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
data=pd.read_csv('learningSet.txt')
data.shape
# Out:
# (95412, 481)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95412 entries, 0 to 95411
# Columns: 481 entries, ODATEDW to GEOCODE2
# dtypes: float64(97), int64(310), object(74)
# memory usage: 350.1+ MB

# %% [markdown]
# Complete the following steps on the categorical columns in the dataset:
#
# Check for null values in all the columns

# %%
categorical=data.select_dtypes(np.object)
categorical
# Out:
#       OSOURCE STATE    ZIP MAILCODE PVASTATE NOEXCH RECINHSE RECP3 RECPGVG  \
# 0         GRI    IL  61081                        0
# 1         BOA    CA  91326                        0
# 2         AMH    NC  27017                        0
# 3         BRY    CA  95953                        0
# 4                FL  33176                        0        X     X
# ...       ...   ...    ...      ...      ...    ...      ...   ...     ...
# 95407     ASE    AK  99504                        0
# 95408     DCD    TX  77379                        0
# 95409     MBC    MI  48910                        0              X
# 95410     PRV    CA  91320                        0        X
# 95411     MCC    NC  28409                        0        X             X
#
#       RECSWEEP MDMAUD DOMAIN CLUSTER AGEFLAG HOMEOWNR CHILD03 CHILD07 CHILD12  \
# 0                XXXX     T2      36
# 1                XXXX     S1      14       E        H
# 2                XXXX     R2      43                U
# ...

# %%
100*categorical['GEOCODE2'].value_counts()/len(categorical['GEOCODE2'])
# Out:
# A    36.142204
# B    29.875697
# D    17.377269
# C    16.270490
#       0.195992
# Name: GEOCODE2, dtype: float64

# %%
categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95412 entries, 0 to 95411
# Data columns (total 74 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OSOURCE   95412 non-null  object
#  1   STATE     95412 non-null  object
#  2   ZIP       95412 non-null  object
#  3   MAILCODE  95412 non-null  object
#  4   PVASTATE  95412 non-null  object
#  5   NOEXCH    95412 non-null  object
#  6   RECINHSE  95412 non-null  object
#  7   RECP3     95412 non-null  object
#  8   RECPGVG   95412 non-null  object
#  9   RECSWEEP  95412 non-null  object
#  10  MDMAUD    95412 non-null  object
#  11  DOMAIN    95412 non-null  object
#  12  CLUSTER   95412 non-null  object
#  13  AGEFLAG   95412 non-null  object
#  14  HOMEOWNR  95412 non-null  object
#  15  CHILD03   95412 non-null  object
#  16  CHILD07   95412 non-null  object
#  17  CHILD12   95412 non-null  object
#  18  CHILD18   95412 non-null  object
#  19  GENDER    95412 non-null  object
# ...

# %%
categorical.isna().sum().sum()
# Out:
# 132

# %% [markdown]
# Exclude the following variables by looking at the definitions. Create a new empty list called drop_list. We will append this list and then drop all the columns in this list later:
#
# OSOURCE - symbol definitions not provided, too many categories
# ZIP CODE - we are including state already

# %%
#hacer lista

# %%
drop_list = []

# %%
drop_list.append (['OSOUERCE', 'ZIP'])

# %%
drop_list
# Out:
# [['OSOUERCE', 'ZIP']]

# %% [markdown]
# Identifique las columnas que faltan en más del 85 % de los valores

# %%
nulls_percent_df=pd.DataFrame(data.isna().sum()/len(data)).reset_index()
nulls_percent_df.columns=['column_name','nulls_percentage']

# %%
columns_above_threshold= nulls_percent_df[nulls_percent_df['nulls_percentage']>.85]
len(columns_above_threshold)

#columns_above_threshold

drop_list.append(list(columns_above_threshold['column_name']))
drop_list
# Out:
# [['OSOUERCE', 'ZIP'],
#  ['NUMCHLD',
#   'RDATE_3',
#   'RDATE_4',
#   'RDATE_5',
#   'RDATE_6',
#   'RDATE_7',
#   'RDATE_10',
#   'RDATE_13',
#   'RDATE_15',
#   'RDATE_17',
#   'RDATE_20',
#   'RDATE_21',
#   'RDATE_23',
#   'RAMNT_3',
#   'RAMNT_4',
#   'RAMNT_5',
#   'RAMNT_6',
#   'RAMNT_7',
#   'RAMNT_10',
#   'RAMNT_13',
#   'RAMNT_15',
#   'RAMNT_17',
#   'RAMNT_20',
#   'RAMNT_21',
#   'RAMNT_23']]

# %%
#NO hay columnas con mas del 85%

# %% [markdown]
# Eliminar esas columnas del marco de datos

# %%
## Nada que eliminar

# %% [markdown]
# Reduzca el número de categorías en la columna GENDER. La columna solo debe tener "M" para hombres, "F" para mujeres y "otro" para el resto
#
# Tenga en cuenta que hay algunos valores nulos en la columna. Primero reemplazaremos esos valores nulos usando el siguiente código:
# print(categorical['GENDER'].value_counts())
# categorical['GENDER'] = categorical['GENDER'].fillna('F')

# %%
categorical['GENDER'].value_counts()
# Out:
# F    51277
# M    39094
#       2957
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %%
print(categorical['GENDER'].value_counts())
categorical['GENDER'] = categorical['GENDER'].fillna('F')
categorical['GENDER'].value_counts()
categorical['GENDER'] = categorical['GENDER'].replace('  ','F')
# Out:
# F    54234
# M    39094
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %%
def clean_gender (x):
  if x in ['F','M']:
        return x
  else:
        return 'other'

categorical['GENDER'] = list(map(clean_gender, categorical['GENDER']))

# %%
categorical['GENDER'].value_counts()
# Out:
# F        54234
# M        39094
# other     2084
# Name: GENDER, dtype: int64
